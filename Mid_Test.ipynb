# %%
import numpy as np
import pandas as pd

# %%
# Read the data
data = pd.read_csv('discord_files.csv')
display(data)
# Out:
#     1064126013803610212          primetogo  \
# 0   1064125804868534283                林晓龙
# 1   1064125556221820968           JvstJane
# 2   1064125547434758194           JvstJane
# 3   1064125500903137351                林晓龙
# 4   1064125291607379968          Theerawat
# ..                  ...                ...
# 95  1064094964855873606              narze
# 96  1064094956505022524  IntegrationByPart
# 97  1064094904529190943              narze
# 98  1064094899118551040  IntegrationByPart
# 99  1064094854042370068  IntegrationByPart
#
#                            ยาหอมมันจะเป็นขวดอีกแบบนึง  \
# 0   อั้มบอกว่ามันคือยาหอมหรือไม่ก็ขวดแบบนี้เป็นยาห...
# 1                                            ขวดเขียว
# 2                                             ใช่แล้ว
# 3   ใช่ขวดสีเขียวไหมเคยเจออยู่ครั้งหนึ่งงงงงงง นึก...
# 4                                       #ทีมโป๊ยเซียน
# ..                                                ...
# 95                                                ถถถ
# ...
