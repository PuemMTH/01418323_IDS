# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sr = pd.Series([30,20,10,50,90])
# Shift + Tab : show docstring

# %%
sr.plot( kind = 'line' , style = 'gD-.' ,alpha = 0.8 , grid = False , title = 'Test'
 ,xlabel = 'X',ylabel = 'Y',xlim = [1,3] , xticks = [1,2,3] )
#  kind : line, bar, barh, hist, kde, density, pie, scatter, hexbin, box, area, hist, kde, density, pie, scatter, hexbin, box, area
#  style : color, marker, line
#  alpha : คือ ความโปร่งใส ของสี
#  grid : แสดงเส้น grid
#  title : ชื่อกราฟ
#  xlabel : ชื่อแกน x
#  ylabel : ชื่อแกน y
#  xlim : ขอบเขตของแกน x
#  xticks : ตำแหน่งของแกน x
# Out:
# <AxesSubplot: title={'center': 'Test'}, xlabel='X', ylabel='Y'>

# %%
df = pd.DataFrame( np.random.randint(0,100,[6,3]),columns = list('ABC'))
df.plot( title = 'Profit',legend=True , kind = 'line', style = ['gD--','rs-.','b+:'] )
# Out:
# <AxesSubplot: title={'center': 'Profit'}>

# %%
sns.get_dataset_names()
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(10,5))
# sns.countplot(x = 'sex',data = tips)
sns.countplot(
    x = 'sex',
    data=tips,
    hue='smoker',
    palette='Set1',
)
plt.show()

# %%
sns.histplot( tips['total_bill'],kde = True , bins = 10 )
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot( data = tips , x = 'sex' , y='tip' )
# Out:
# <AxesSubplot: xlabel='sex', ylabel='tip'>

# %%
sns.countplot( data = tips , x = 'sex')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
sns.histplot( tips['sex'] )
# Out:
# <AxesSubplot: xlabel='sex', ylabel='Count'>

# %%
sns.histplot(data = tips, x = 'tip' ) # sns.histplot( tips['tip'] )
# Out:
# <AxesSubplot: xlabel='tip', ylabel='Count'>

# %%
sns.countplot( data = tips , x = 'tip')
# Out:
# <AxesSubplot: xlabel='tip', ylabel='count'>

# %%
# sns.histplot( tips['tip'] )
sns.histplot( tips['tip'] , bins = 10 , kde=True )
plt.show()

# %%
sns.countplot( data = tips , x = 'day',palette='magma')
# Out:
# <AxesSubplot: xlabel='day', ylabel='count'>

# %%
# https://matplotlib.org/stable/tutorials/colors/colormaps.html
sns.boxplot( data = tips , x = 'day' , y = 'total_bill' )
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot( data = tips , y = 'day' , x = 'total_bill' )
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='day'>

# %%
sns.boxplot(data = tips ,orient = 'v' )
# orient : h = horizontal , v = vertical
# Out:
# <AxesSubplot: >

# %%
sns.boxplot( data = tips , x = 'day' , y = 'tip', palette='')
# colormap
# plt.cm.Blues

# parllete : https://matplotlib.org/stable/tutorials/colors/colormaps.html
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.boxplot( data = tips , x = 'day' , y = 'tip' ,hue = 'sex' )
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.violinplot( data = tips , x = 'day' , y = 'tip')
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.violinplot( data = tips , x = 'day' , y = 'tip' , hue = 'smoker')
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.violinplot( data = tips , x = 'day' , y = 'tip' , hue = 'smoker' , split = True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data = tips , x = 'day' , y = 'tip' )
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data = tips , x = 'day' , y = 'tip' , jitter = 0.0 )
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data = tips , x = 'day' , y = 'tip' ,hue = 'sex' )
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(data = tips , x = 'day' , y = 'total_bill',hue = 'sex')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data = tips , x = 'day' , y = 'total_bill',color = 'black')
sns.violinplot(data = tips , x = 'day' , y = 'total_bill')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot( data = tips ,x='total_bill' ,y='tip' )
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot( data = tips ,x='total_bill' ,y='tip' )
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot( data = tips ,x='total_bill' ,y='tip' )

# %%
sns.jointplot( data = tips ,x='total_bill' ,y='tip' ,kind = 'reg' )

# %%
sns.jointplot( data = tips ,x='total_bill' ,y='tip', kind = 'hex')

# %%
sns.jointplot( data = tips ,x='total_bill' ,y='tip' , hue = 'smoker' )

# %%
g = sns.JointGrid(data = tips , x = 'total_bill', y = 'tip')
g.plot( sns.regplot , sns.boxplot )
plt.show()

# %%
sns.pairplot( tips )

# %%
sns.pairplot( tips , hue = 'sex' )

# %%
g = sns.pairplot( tips , hue = 'sex' )
g.map_diag( plt.hist )
g.map_upper( plt.scatter )
g.map_lower( sns.kdeplot )

# %%
g = sns.PairGrid( tips , hue = 'sex' )
g.map_diag( plt.hist )
g.map_upper( plt.scatter )
g.map_lower( sns.kdeplot )

# %%
sns.histplot( data = tips,x = 'tip' , hue = 'time',palette='magma' )
# Out:
# <AxesSubplot: xlabel='tip', ylabel='Count'>

# %%
g = sns.FacetGrid(tips , col = 'time' , row = 'smoker')
g.map( plt.hist , 'tip' )

# %%
g = sns.FacetGrid(tips , col = 'time' , hue = 'smoker')
g.map( plt.hist , 'tip' ).add_legend()

# %%
g = sns.FacetGrid(tips , col = 'time' , row = 'smoker' , hue = 'sex',palette='magma')
g.map( plt.scatter , 'tip','total_bill' ).add_legend()

# %%
sns.regplot(data = tips , x = 'total_bill' , y = 'tip')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data = tips , x = 'total_bill' , y = 'tip',col = 'day',hue = 'smoker',palette='magma')

# %%
sns.lmplot(data = tips , x = 'total_bill' , y = 'tip',hue = 'smoker',markers= ['s','v']
 , scatter_kws = {'s':100} )

# %%
sns.lmplot(data = tips , x = 'total_bill' , y = 'tip',hue = 'smoker',markers= ['s','v']
 , scatter_kws = {'s':50} ,height = 5,aspect = 1.5 )

# %%
plt.figure(figsize=(10,5))
sns.countplot(data = tips , x = 'sex',palette = 'bwr')
sns.set_style('darkgrid')
sns.despine() # left = True
sns.set_context('poster',font_scale = 1.3)

# %%
plt.style.use('default')

# %%
tips.corr()
# Out:
# C:\Users\puemm\AppData\Local\Temp\ipykernel_14204\3825555837.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.figure(figsize=[5,4])
sns.heatmap( tips.corr() , cmap='coolwarm' ,annot = True )
# Out:
# C:\Users\puemm\AppData\Local\Temp\ipykernel_14204\2279541772.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap( tips.corr() , cmap='coolwarm' ,annot = True )
# <AxesSubplot: >

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
pvf = flights.pivot_table( values = 'passengers' , index = 'month' , columns = 'year' )
pvf
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(pvf)
# Out:
# <AxesSubplot: xlabel='year', ylabel='month'>

# %%
plt.figure(figsize=[5,4])
sns.heatmap(pvf, linecolor = 'white' ,lw = 1)
# Out:
# <AxesSubplot: xlabel='year', ylabel='month'>

# %%
sns.heatmap(pvf, linecolor = 'white' ,lw = 1, cmap='CMRmap')
# Out:
# <AxesSubplot: xlabel='year', ylabel='month'>

# %%
sns.lmplot(data = tips , x = 'total_bill' , y = 'tip',col = 'day',hue = 'smoker',palette='magma')

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.scatterplot(data = iris , x = 'sepal_length' , y = 'sepal_width' , hue = 'species' );

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
pvf = flights.pivot_table( values = 'passengers' , index = 'month' , columns = 'year' )
pvf

# %%
sns.heatmap(pvf)
# Out:
# <AxesSubplot: xlabel='year', ylabel='month'>
